# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
from sklearn import svm
pd.set_option("max_columns", 50)

diab_final = pd.read_csv("data/clean_data_2class.csv")

from sklearn.model_selection import train_test_split

# columns need to be deleted since they are not adding any value
del_cols = ["Unnamed: 0", "encounter_id", "patient_nbr", "weight", "discharge_disposition", 
            "admission_source", "payer_code", "medical_specialty", "admisison_type"]

for col in del_cols:
    if col in diab_final.columns:
        diab_final.drop(col, inplace=True, axis = 1)
        #del diab_final[col]

# %%
pick_list = [ "time_in_hospital", "num_lab_procedures", "num_procedures", "num_medications", "number_outpatient", "number_emergency", "number_inpatient", "diag_1", "diag_3", "number_diagnoses"]

# %%
diab_corr = diab_final[pick_list]

# %%
# %matplotlib inline
plt.matshow(diab_corr.corr())

# %%
diab_corr.corr()
# Out:
#                     time_in_hospital  num_lab_procedures  num_procedures  \
# time_in_hospital            1.000000            0.318632        0.191164
# num_lab_procedures          0.318632            1.000000        0.058710
# num_procedures              0.191164            0.058710        1.000000
# num_medications             0.464212            0.267863        0.382952
# number_outpatient          -0.010913           -0.008625       -0.026453
# number_emergency           -0.010508           -0.002142       -0.038723
# number_inpatient            0.072282            0.039198       -0.067535
# number_diagnoses            0.211225            0.150257        0.058973
#
#                     num_medications  number_outpatient  number_emergency  \
# time_in_hospital           0.464212          -0.010913         -0.010508
# num_lab_procedures         0.267863          -0.008625         -0.002142
# num_procedures             0.382952          -0.026453         -0.038723
# num_medications            1.000000           0.042652          0.012127
# number_outpatient          0.042652           1.000000          0.091033
# number_emergency           0.012127           0.091033          1.000000
# number_inpatient           0.062905           0.105979          0.267174
# number_diagnoses           0.241501           0.091414          0.054616
#
#                     number_inpatient  number_diagnoses
# time_in_hospital            0.072282          0.211225
# num_lab_procedures          0.039198          0.150257
# num_procedures             -0.067535          0.058973
# num_medications             0.062905          0.241501
# number_outpatient           0.105979          0.091414
# number_emergency            0.267174          0.054616
# number_inpatient            1.000000          0.101244
# number_diagnoses            0.101244          1.000000

# %%
import pandas as pd
pd.set_option("max_columns", 50)

# %%
diab_data = pd.read_csv("data/Clean_Data_red_dim.csv")

# %%
diab_data.head()
# Out:
#    Unnamed: 0             race  gender      age  time_in_hospital  \
# 0           1        Caucasian  Female  [10-20)                 3
# 1           2  AfricanAmerican  Female  [20-30)                 2
# 2           3        Caucasian    Male  [30-40)                 2
# 3           4        Caucasian    Male  [40-50)                 1
# 4           5        Caucasian    Male  [50-60)                 3
#
#    num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 0                  59               0               18                  0
# 1                  11               5               13                  2
# 2                  44               1               16                  0
# 3                  51               0                8                  0
# 4                  31               6               16                  0
#
#    number_emergency  number_inpatient diag_1 diag_2 diag_3  number_diagnoses  \
# 0                 0                 0   ENMI   ENMI   ENMI                 9
# 1                 0                 1    PCC   ENMI    CFI                 6
# 2                 0                 0    IPD   ENMI    CSD                 7
# 3                 0                 0     NP     NP   ENMI                 5
# 4                 0                 0    CSD    CSD   ENMI                 9
#
#   max_glu_serum A1Cresult metformin repaglinide nateglinide chlorpropamide  \
# 0          None      None        No          No          No             No
# 1          None      None        No          No          No             No
# 2          None      None        No          No          No             No
# 3          None      None        No          No          No             No
# 4          None      None        No          No          No             No
#
#   glimepiride acetohexamide glipizide glyburide tolbutamide pioglitazone  \
# 0          No            No        No        No          No           No
# 1          No            No    Steady        No          No           No
# 2          No            No        No        No          No           No
# 3          No            No    Steady        No          No           No
# 4          No            No        No        No          No           No
#
#   rosiglitazone acarbose miglitol troglitazone tolazamide examide citoglipton  \
# 0            No       No       No           No         No      No          No
# 1            No       No       No           No         No      No          No
# 2            No       No       No           No         No      No          No
# 3            No       No       No           No         No      No          No
# 4            No       No       No           No         No      No          No
#
#   insulin glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0      Up                  No                  No                       No
# 1      No                  No                  No                       No
# 2      Up                  No                  No                       No
# 3  Steady                  No                  No                       No
# 4  Steady                  No                  No                       No
#
#   metformin-rosiglitazone metformin-pioglitazone change diabetesMed  \
# 0                      No                     No     Ch         Yes
# 1                      No                     No     No         Yes
# 2                      No                     No     Ch         Yes
# 3                      No                     No     Ch         Yes
# 4                      No                     No     No         Yes
#
#   readmitted      admission_type
# 0        YES  Physician Referral
# 1         NO  Physician Referral
# 2         NO  Physician Referral
# 3         NO  Physician Referral
# 4        YES     Clinic Referral

# %%
diab_data['readmitted'] = diab_data['readmitted'].map({">30": "YES", "<30":"YES", "NO":"NO"})

# %%
diab_final = diab_data

# %%
# columns need to be deleted since they are not adding any value
del_cols = ["Unnamed: 0", "encounter_id", "patient_nbr", "weight", "discharge_disposition", 
            "admission_source", "payer_code", "medical_specialty", "admisison_type"]

for col in del_cols:
    if col in diab_final.columns:
        diab_final.drop(col, inplace=True, axis = 1)
        #del diab_final[col]

# %%
diab_clean = diab_final.to_csv("data/clean_data_2class.csv")
